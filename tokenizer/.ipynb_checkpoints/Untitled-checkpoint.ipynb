# %% [markdown]
# # building a simple tokenizer

# %%
#step 1 :load a sample text file

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from pypdf import pdfReader
#
# ModuleNotFoundError: No module named 'pypdf'
